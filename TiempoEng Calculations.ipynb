# %%
import pandas as pd

path_sp = r'C:/Users/ggalina/Engineering Metrics/Sharepoint Data.xlsx'
df_cck = pd.read_excel(path_sp,sheet_name= 'CCK Data')
filt_ccktime = (df_cck['Time - Complete Information Received'].dt.year == 2020) & (df_cck['Time - Request Completed'].dt.year ==2020)
df_cck1 =(df_cck[filt_ccktime]['Time - Request Completed'].dropna() - df_cck[filt_ccktime]['Time - Complete Information Received'].dropna()).astype('timedelta64[h]')
df_cck1[df_cck1 < 0] = None
df_cck1.dropna().mean()
# Out:
# 101.93055555555556

# %%
df_times = df_cck.loc[1970:2287,['Time - Complete Information Received', 'Time - Request Completed' ]].dropna().tail(50)

# %%
df_times[filt_ccktime].join(df_cck1.rename('TiempoEng'))
# Out:
# c:\users\ggalina\miniconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#      Time - Complete Information Received Time - Request Completed  TiempoEng
# 2154                  2020-02-10 12:00:00      2020-02-14 11:40:00       95.0
# 2155                  2020-02-10 08:51:00      2020-02-19 18:37:00      225.0
# 2162                  2020-02-12 13:58:00      2020-02-18 06:30:00      136.0
# 2172                  2020-02-14 22:17:00      2020-02-26 23:20:00      289.0
# 2176                  2020-02-17 12:56:00      2020-02-18 09:59:00       21.0
# 2177                  2020-02-18 09:00:00      2020-02-20 18:20:00       57.0
# 2179                  2020-02-17 15:00:00      2020-02-17 17:00:00        2.0
# 2180                  2020-02-17 18:52:00      2020-02-18 06:30:00       11.0
# ...
